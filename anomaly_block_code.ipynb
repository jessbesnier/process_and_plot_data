# %%
### anomaly big chart

# %%
import numpy as np
import pandas as pd

import datetime as dt


import numpy as np

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.colors as colors

# %%
#def prepare_data(variable_name,column_name):
    #p_anomaly = pd.read_csv('D:/2021/la_plata/gldas_da_anom/' + variable_name + '_anomaly.csv')
    #p_anomaly_savg = p_anomaly.groupby('time').agg({column_name + '(mm)': ['mean']})
    #return p_anomaly_savg

# %%
#p_anomal = prepare_data('p','P')
#et_anomal = prepare_data('et','ET')
#r_anomal = prepare_data('r','R')
#gw_anomaly = prepare_data('gw','GW')
#twsa = prepare_data('grace','TWSA')

# %%
p_anomal = pd.read_csv('D:/2021/la_plata/updated_data/anomaly_csv/p_anomaly.csv')
et_anomal = pd.read_csv('D:/2021/la_plata/updated_data/anomaly_csv/et_anomaly.csv')
r_anomal= pd.read_csv('D:/2021/la_plata/updated_data/anomaly_csv/r_anomaly.csv')
gw_anomaly= pd.read_csv('D:/2021/la_plata/updated_data/anomaly_csv/gw_anomaly.csv')

rzsm_anomaly=pd.read_csv('D:/2021/la_plata/updated_data/anomaly_csv/rz_anomaly.csv')
ssm_anomaly=pd.read_csv('D:/2021/la_plata/updated_data/anomaly_csv/ssm_anomaly.csv')
psm_anomaly=pd.read_csv('D:/2021/la_plata/updated_data/anomaly_csv/psm_anomaly.csv')

# %%
p_anomaly_savg = p_anomal.groupby('time').agg({'P(mm)': ['mean']})
et_anomaly_savg =et_anomal.groupby('time').agg({'ET(mm)': ['mean']})
r_anomaly_savg = r_anomal.groupby('time').agg({'R(mm)': ['mean']})
gw_anomaly_savg = gw_anomaly.groupby('time').agg({'GW(mm)': ['mean']})
#twsa = twsa_r.groupby('time').agg({'TWSA(mm)':['mean']})
rzsm_anomaly_savg = rzsm_anomaly.groupby('time').agg({'RZ(mm)': ['mean']})
ssm_anomaly_savg = ssm_anomaly.groupby('time').agg({'SSM(mm)': ['mean']})
psm_anomaly_savg = psm_anomaly.groupby('time').agg({'RZ(mm)': ['mean']})

# %%
p_anomaly = p_anomaly_savg*86400*30
et_anomaly = et_anomaly_savg*86400*30
r_anomaly = r_anomaly_savg*86400*30

# %%
p_anomaly.index = pd.to_datetime(p_anomaly.index, format = '%Y-%m-%d')
et_anomaly.index = pd.to_datetime(et_anomaly.index, format = '%Y-%m-%d')
r_anomaly.index = pd.to_datetime(r_anomaly.index, format = '%Y-%m-%d')
gw_anomaly_savg.index = pd.to_datetime(gw_anomaly_savg.index, format = '%Y-%m-%d')
#twsa.index = pd.to_datetime(twsa.index, format = '%Y-%m-%d')

d = pd.date_range(start = '01/01/2015', end = '11/1/2021', freq = 'MS')

plt.style.use('tableau-colorblind10')
plt.rcParams.update({'font.size': 14})

fig,axs = plt.subplots(4,1, figsize=(14,18),sharex=True)

axs[0].plot(p_anomaly['01/01/2015':], marker = '', color='#5e81b5', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(et_anomaly['01/01/2015':], marker = '', color = '#ec6235',linewidth=1, markeredgewidth = 0.0)
axs[2].plot(r_anomaly['01/01/2015':],marker = '',color = '#e19c24',linewidth=1, markeredgewidth = 0.0)
axs[3].plot(gw_anomaly_savg['01/01/2015':], marker = '', color = '#8fb131', linewidth=1, markeredgewidth = 0.0) 
#axs[4].plot(twsa['2015-01-01':'2015-06-01'], marker = 'o', color='#8778b3',linewidth=1, markeredgewidth = 0.0)
#axs[4].plot(twsa['2015-07-01':'2015-10-01'],marker = 'o', color='#8778b3',linewidth=1, markeredgewidth = 0.0)
#axs[4].plot(twsa['2015-12-01':'2016-04-01'],marker = 'o', color='#8778b3',linewidth=1, markeredgewidth = 0.0)
#axs[4].plot(twsa['2016-05-01':'2016-09-01'],marker = 'o', color='#8778b3',linewidth=1, markeredgewidth = 0.0)
#axs[4].plot(twsa['2016-11-01':'2017-02-01'],marker = 'o', color='#8778b3',linewidth=1, markeredgewidth = 0.0)
#axs[4].plot(twsa['2017-04-01':'2017-06-01'],marker = 'o', color='#8778b3',linewidth=1, markeredgewidth = 0.0)
#axs[4].plot(twsa['2018-06-01':'2018-08-01'],marker = 'o', color='#8778b3',linewidth=1, markeredgewidth = 0.0)
#axs[4].plot(twsa['2018-11-01':'2021-05-01'],marker = 'o', color='#8778b3',linewidth=1, markeredgewidth = 0.0)

axs[0].set_ylabel('Precipitation (mm)', fontsize = 18)
axs[1].set_ylabel('Evapotranspiration (mm)',fontsize = 18)
axs[2].set_ylabel('Runoff (mm)',fontsize = 18)
axs[3].set_ylabel('Groundwater (mm)',fontsize = 18)
#axs[4].set_ylabel('TWSA (mm)')

axs[3].set_xlabel("Year")

axs[0].set_ylim([-65,65])
axs[1].set_ylim([-20,20])
axs[2].set_ylim([-25,25])
axs[3].set_ylim([-100,100])
#axs[4].set_ylim([-10,10])

axs[0].grid(which='major',axis='both')
axs[1].grid(which='major',axis='both')
axs[2].grid(which='major',axis='both')
axs[3].grid(which='major',axis='both')
#axs[4].grid(which='major',axis='both')


# add horizontal zero line for all plots 
axs[0].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)
axs[1].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)
axs[2].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)
axs[3].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)
#axs[4].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)


fig.suptitle('La Plata River Basin Monthly Anomalies (GLDAS)', fontsize = 24)
fig.tight_layout()
fig.subplots_adjust(top=0.95)


#axs.tick_params(bottom = True, top = False, left = True, right = False)

#axs.set_major_locator(mdates.YearLocator(2))
#axs.set_major_formatter(mdates.DateFormatter('%Y'))


fig.tight_layout()

plt.savefig('D:/2021/la_plata/figures/anomalies/all_anomaly_updated_2022_bigg.png')

# %%
rzsm = rzsm_anomaly_savg/1000
ssm = ssm_anomaly_savg/2
psm = psm_anomaly_savg/4958.2

# %%
ssm.index = pd.to_datetime(ssm.index, format = '%Y-%m-%d')
rzsm.index = pd.to_datetime(rzsm.index, format = '%Y-%m-%d')
psm.index = pd.to_datetime(psm.index, format = '%Y-%m-%d')


d = pd.date_range(start = '01/01/2015', end = '11/1/2021', freq = 'MS')

plt.style.use('tableau-colorblind10')
plt.rcParams.update({'font.size': 14})

fig,axs = plt.subplots(3,1, figsize=(12,10),sharex=True)

axs[0].plot(ssm['01/01/2015':], marker = '', color='#822f72', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(rzsm['01/01/2015':], marker = '', color = '#4b5320',linewidth=1, markeredgewidth = 0.0)
axs[2].plot(psm['01/01/2015':],marker = '',color = '#53868b',linewidth=1, markeredgewidth = 0.0)


axs[0].set_ylabel('Surface SM (m3/m3)', fontsize = 18)
axs[1].set_ylabel('Root Zone SM (m3/m3)', fontsize = 18)
axs[2].set_ylabel('Profile SM (m3/m3)', fontsize = 18 )


axs[2].set_xlabel("Year")

axs[0].set_ylim([-0.4,0.4])
axs[1].set_ylim([-0.025,0.025])
axs[2].set_ylim([-0.025,0.025])


axs[0].grid(which='major',axis='both')
axs[1].grid(which='major',axis='both')
axs[2].grid(which='major',axis='both')



# add horizontal zero line for all plots 
axs[0].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)
axs[1].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)
axs[2].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)



fig.suptitle('La Plata River Basin Monthly Soil Moisture Anomalies (GLDAS)')
fig.tight_layout()
fig.subplots_adjust(top=0.95)




#axs.tick_params(bottom = True, top = False, left = True, right = False)

#axs.set_major_locator(mdates.YearLocator(2))
#axs.set_major_formatter(mdates.DateFormatter('%Y'))


fig.tight_layout()


plt.savefig('D:/2021/la_plata/figures/anomalies/all_SManomm.png')

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# Spatial Plots for Anomalies

# %% [markdown]
# P anomaly Spatial Plot

# %%
#define and get path for P
shapefile_path = r'C:\Users\Jessica Besnier\Documents\Fall 2021\AGU data\river_basin_shape-file'
p_csv=xr.open_dataset('D:/2021/la_plata/panom_gldas/panom_gldas22_laplata_200302-202110.nc', decode_times=False)

units, reference_date = p_csv.time.attrs['units'].split('since')
p_csv['time'] = pd.date_range(start=reference_date, periods=p_csv.sizes['time'], freq='MS')
p_csv_c= p_csv*86400*30

filename = ['la_plata']

def extract_values(i):
    shdf = salem.read_shapefile(shapefile_path + '/' + filename[i]+'.shp')

    p = p_csv_c.panom.salem.roi(shape=shdf)

    p_lat = p.dropna(dim='lat',how='all')
    p_lon = p_lat.dropna(dim='lon',how='all')

    return p_lon

la_plata_imerg = extract_values(0)

# %% [markdown]
# Attempt at making one time series graph with different lines for subbasins

# %%
p_anomaly.index = pd.to_datetime(p_anomaly.index, format = '%Y-%m-%d')
et_anomaly.index = pd.to_datetime(et_anomaly.index, format = '%Y-%m-%d')
r_anomaly.index = pd.to_datetime(r_anomaly.index, format = '%Y-%m-%d')
gw_anomaly_savg.index = pd.to_datetime(gw_anomaly_savg.index, format = '%Y-%m-%d')

d = pd.date_range(start = '01/01/2015', end = '11/1/2021', freq = 'MS')

plt.style.use('tableau-colorblind10')
plt.rcParams.update({'font.size': 14})

fig,axs = plt.subplots(2,1, figsize=(14,18),sharex=False)

axs[0].plot(p_anomaly['01/01/2015':], marker = '', color='#5e81b5', linewidth=1, markeredgewidth = 0.0)
axs[0].plot(et_anomaly['01/01/2015':], marker = '', color = '#ec6235',linewidth=1, markeredgewidth = 0.0)
axs[0].plot(r_anomaly['01/01/2015':],marker = '',color = '#e19c24',linewidth=1, markeredgewidth = 0.0)
axs[0].plot(gw_anomaly_savg['01/01/2015':], marker = '', color = '#8fb131', linewidth=1, markeredgewidth = 0.0) 

axs[0].set_ylabel('Precipitation (mm)', fontsize = 18)

axs[0].set_ylim([-65,65])


axs[0].grid(which='major',axis='both')

# add horizontal zero line for all plots 
axs[0].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)


plt.suptitle('La Plata River Basin Monthly Anomalies', fontsize = 24)


#axs.tick_params(bottom = True, top = False, left = True, right = False)

#axs.set_major_locator(mdates.YearLocator(2))
#axs.set_major_formatter(mdates.DateFormatter('%Y'))


plt.tight_layout()

#plt.savefig('D:/2021/la_plata/figures/anomalies/all_anomaly_updated_2022_big.png')

# %%
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

# %%
test_p= pd.read_csv('D:/2021/la_plata/subbasin_anoms_update/panom_gldas22_ts.csv')

# %%
#test_p['new_date'] = pd.to_datetime(str(test_p['date'])[3:], format='%d%b%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\AGU_data\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# ~\anaconda3\envs\AGU_data\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\JESSIC~1\AppData\Local\Temp/ipykernel_60376/1641678230.py in <module>
# ...

# %%
# anomaly block for all subbasins

df_p= pd.read_csv('D:/2021/la_plata/subbasin_anoms_update/panom_gldas22_ts.csv')
df_et= pd.read_csv('D:/2021/la_plata/subbasin_anoms_update/etanom_gldas22_ts.csv')
df_r= pd.read_csv('D:/2021/la_plata/subbasin_anoms_update/ranom_gldas22_ts.csv')
df_gw= pd.read_csv('D:/2021/la_plata/subbasin_anoms_update/gwsanom_gldas22_ts.csv')
df_tws= pd.read_csv('D:/2021/la_plata/TWS_updated/twsanom_base03-20_gldas22_ts.csv')

#reference_date = pd.date_range(start = '01/01/2015', end = '11/1/2021', freq = 'MS')

# df_p.index = pd.to_datetime(df_p['date.1'])
# df_et.index = pd.to_datetime(df_et['date.1'])
# df_r.index = pd.to_datetime(df_r['date.1'])
# df_gw.index = pd.to_datetime(df_gw['date.1'])
# df_tws.index = pd.to_datetime(df_tws['date.1'])

plt.style.use('default')
plt.rcParams.update({'font.size': 14})

fig,axs = plt.subplots(5,1, figsize=(14,18),sharex=True)
#['2015':]

Upper_Paraguay = axs[0].plot(df_p.Up_Paraguay, marker = '', color='#990b11', linewidth=1, markeredgewidth = 0.0, label = 'Upper Paraguay')
Upper_Parana= axs[0].plot(df_p.Up_Parana, marker = '', color='#23b936', linewidth=1, markeredgewidth = 0.0)
Lower_Paraguay = axs[0].plot(df_p.Lo_Paraguay, marker = '.', color='#990b11', linewidth=1, markeredgewidth = 0.0)
Lower_Parana = axs[0].plot(df_p.Lo_Parana, marker = '.', color='#23b936', linewidth=1, markeredgewidth = 0.0)
Upper_Uruguay= axs[0].plot(df_p.Up_Ulguay, marker = '', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
Lower_Uruguay= axs[0].plot(df_p.Lo_Ulguay, marker = '.', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
Rio_de_la_Plata = axs[0].plot(df_p.Rio_Plata, marker = '', color='#e8bd39', linewidth=1, markeredgewidth = 0.0)
Entire_Basin= axs[0].plot(df_p.Laplata, marker = '', color='#000000', linewidth=1.5, markeredgewidth = 0.0)

axs[0].set_ylabel('Precipitation (mm)', fontsize = 20)

axs[1].plot(df_et.Up_Paraguay, marker = '', color='#990b11', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_et.Up_Parana, marker = '', color='#23b936', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_et.Lo_Paraguay, marker = '.', color='#990b11', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_et.Lo_Parana, marker = '.', color='#23b936', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_et.Up_Ulguay, marker = '', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_et.Lo_Ulguay, marker = '.', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_et.Rio_Plata, marker = '', color='#e8bd39', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_et.Laplata, marker = '', color='#000000', linewidth=1.5, markeredgewidth = 0.0)

axs[1].set_ylabel('Evapotranspiration (mm)', fontsize = 20)

axs[2].plot(df_r.Up_Paraguay, marker = '', color='#990b11', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_r.Up_Parana, marker = '', color='#23b936', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_r.Lo_Paraguay, marker = '.', color='#990b11', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_r.Lo_Parana, marker = '.', color='#23b936', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_r.Up_Ulguay, marker = '', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_r.Lo_Ulguay, marker = '.', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_r.Rio_Plata, marker = '', color='#e8bd39', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_r.Laplata, marker = '', color='#000000', linewidth=1.5, markeredgewidth = 0.0)

axs[2].set_ylabel('Runoff (mm)', fontsize = 20)

axs[3].plot(df_gw.Up_Paraguay, marker = '', color='#990b11', linewidth=1, markeredgewidth = 0.0)
axs[3].plot(df_gw.Up_Parana, marker = '', color='#23b936', linewidth=1, markeredgewidth = 0.0)
axs[3].plot(df_gw.Lo_Paraguay, marker = '.', color='#990b11', linewidth=1, markeredgewidth = 0.0)
axs[3].plot(df_gw.Lo_Parana, marker = '.', color='#23b936', linewidth=1, markeredgewidth = 0.0)
axs[3].plot(df_gw.Up_Ulguay, marker = '', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
axs[3].plot(df_gw.Lo_Ulguay, marker = '.', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
axs[3].plot(df_gw.Rio_Plata, marker = '', color='#e8bd39', linewidth=1, markeredgewidth = 0.0)
axs[3].plot(df_gw.Laplata, marker = '',color='#000000', linewidth=1.5, markeredgewidth = 0.0)

axs[3].set_ylabel('Groundwater (mm)', fontsize = 20)

axs[4].plot(df_tws.Up_Paraguay, marker = '', color='#990b11', linewidth=1, markeredgewidth = 0.0)
axs[4].plot(df_tws.Up_Parana, marker = '', color='#23b936', linewidth=1, markeredgewidth = 0.0)
axs[4].plot(df_tws.Lo_Paraguay, marker = '.', color='#990b11', linewidth=1, markeredgewidth = 0.0)
axs[4].plot(df_tws.Lo_Parana, marker = '.', color='#23b936', linewidth=1, markeredgewidth = 0.0)
axs[4].plot(df_tws.Up_Ulguay, marker = '', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
axs[4].plot(df_tws.Lo_Ulguay, marker = '.', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
axs[4].plot(df_tws.Rio_Plata, marker = '', color='#e8bd39', linewidth=1, markeredgewidth = 0.0)
axs[4].plot(df_tws.Laplata, marker = '', color='#000000', linewidth=1.5, markeredgewidth = 0.0)

axs[4].set_ylabel('Total Water Storage (cm)', fontsize = 20)
#d = pd.date_range(start = '146', end = '11/1/2021', freq = 'MS')


axs[0].set_ylim([-200, 200])
axs[0].set_xlim([146, 230])

axs[1].set_ylim([-85,85])
axs[1].set_xlim([146, 230])

axs[2].set_ylim([-150, 250])
axs[2].set_xlim([146, 230])

axs[3].set_ylim([-200, 200])
axs[3].set_xlim([146, 230])

axs[4].set_ylim([-25, 25])
axs[4].set_xlim([146, 230])

fig.suptitle('La Plata River Basin Monthly Anomalies (GLDAS)', fontsize = 24)
axs[4].legend(['Upper Paraguay','Upper Parana','Lower Paraguay','Lower Parana','Upper Uruguay','Lower Uruguay','Rio de la Plata','Entire Basin'],loc='lower center',bbox_to_anchor=(0.5,-0.4),ncol=4)



#axs[0].tick_params(bottom = True, top = False, left = True, right = False)

axs[0].xaxis.set_major_locator(mdates.YearLocator(2))
axs[0].xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
# legend_elements = [Line2D([0], [0], color='b', lw=4, label='Line'),Line2D([0], [0], marker='o', color='w', label='Scatter',markerfacecolor='g', markersize=15),]

# plt.legend(loc='best', bbox_to_anchor= (0.5,0.,0.5,0.5) )

axs[0].set_xticks([146,158,170,182,194,206,218],minor=True)
axs[0].set_xticklabels(['2015','2016','2017','2018','2019','2020','2021'],rotation=0,minor=True)

axs[0].grid(which='minor',axis='both')
axs[1].grid(which='minor',axis='both')
axs[2].grid(which='minor',axis='both')
axs[3].grid(which='minor',axis='both')
axs[4].grid(which='minor',axis='both')

axs[0].grid(which='major',axis='both')
axs[1].grid(which='major',axis='both')
axs[2].grid(which='major',axis='both')
axs[3].grid(which='major',axis='both')
axs[4].grid(which='major',axis='both')

# add horizontal zero line for all plots 
axs[0].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)
axs[1].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)
axs[2].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)
axs[3].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)
axs[4].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)

fig.tight_layout()

fig.savefig('D:/2021/la_plata/figures/anomalies/all_anomaly_updtd_2022_sub_finall_thick.png')

# %%
#anoamly block for SM

df_s= pd.read_csv('D:/2021/la_plata/subbasin_anoms_update/sfsmanom_gldas22_ts.csv')
df_rz= pd.read_csv('D:/2021/la_plata/subbasin_anoms_update/rtzsmanom_gldas22_ts.csv')
df_pf= pd.read_csv('D:/2021/la_plata/subbasin_anoms_update/prsmanom_gldas22_ts.csv')


#d = df_p.date 
#reference_date = pd.date_range(start = '01/01/2015', end = '11/1/2021', freq = 'MS')

plt.style.use('default')
plt.rcParams.update({'font.size': 14})

fig,axs = plt.subplots(3,1, figsize=(14,18),sharex=True)

axs[0].plot(df_s.Up_Paraguay, marker = '', color='#990b11', linewidth=1, markeredgewidth = 0.0)
axs[0].plot(df_s.Up_Parana, marker = '', color='#23b936', linewidth=1, markeredgewidth = 0.0)
axs[0].plot(df_s.Lo_Paraguay, marker = '', color='#990b11', linewidth=1,linestyle='dashed', markeredgewidth = 0.0)
axs[0].plot(df_s.Lo_Parana, marker = '', color='#23b936', linewidth=1,linestyle='dashed', markeredgewidth = 0.0)
axs[0].plot(df_s.Up_Ulguay, marker = '', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
axs[0].plot(df_s.Lo_Ulguay, marker = '', color='#1034a6', linewidth=1, linestyle='dashed', markeredgewidth = 0.0)
axs[0].plot(df_s.Rio_Plata, marker = '', color='#e8bd39', linewidth=1, markeredgewidth = 0.0)
axs[0].plot(df_s.Laplata, marker = '', color='#000000', linewidth=1.5, markeredgewidth = 0.0)

axs[0].set_ylabel('Surface Soil Moisture (m3/m3)', fontsize = 20)

axs[1].plot(df_rz.Up_Paraguay, marker = '', color='#990b11', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_rz.Up_Parana, marker = '', color='#23b936', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_rz.Lo_Paraguay, marker = '.', color='#990b11', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_rz.Lo_Parana, marker = '.', color='#23b936', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_rz.Up_Ulguay, marker = '', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_rz.Lo_Ulguay, marker = '.', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_rz.Rio_Plata, marker = '', color='#e8bd39', linewidth=1, markeredgewidth = 0.0)
axs[1].plot(df_rz.Laplata, marker = '', color='#000000', linewidth=1.5, markeredgewidth = 0.0)

axs[1].set_ylabel('Root Zone Soil Moisture (m3/m3)', fontsize = 20)

axs[2].plot(df_pf.Up_Paraguay, marker = '', color='#990b11', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_pf.Up_Parana, marker = '', color='#23b936', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_pf.Lo_Paraguay, marker = '.', color='#990b11', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_pf.Lo_Parana, marker = '.', color='#23b936', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_pf.Up_Ulguay, marker = '', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_pf.Lo_Ulguay, marker = '.', color='#1034a6', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_pf.Rio_Plata, marker = '', color='#e8bd39', linewidth=1, markeredgewidth = 0.0)
axs[2].plot(df_pf.Laplata, marker = '', color='#000000', linewidth=1.5, markeredgewidth = 0.0)

axs[2].set_ylabel('Profile Soil Moisture (m3/m3)', fontsize = 20)

#d = pd.date_range(start = '146', end = '11/1/2021', freq = 'MS')

axs[0].set_ylim([-0.75, 0.75])
axs[0].set_xlim([142, 230])

axs[1].set_ylim([-0.06,0.06])
axs[1].set_xlim([142, 230])

axs[2].set_ylim([-0.05, 0.05])
axs[2].set_xlim([142, 230])

plt.suptitle('La Plata River Basin Monthly Anomalies (GLDAS)', fontsize = 24)

axs[2].legend(['Upper Paraguay','Upper Parana','Lower Paraguay','Lower Parana','Upper Uruguay','Lower Uruguay','Rio de la Plata','Entire Basin'],loc='lower center',bbox_to_anchor=(0.5,-0.25),ncol=4)

axs[2].set_xticks([146,158,170,182,194,206,218],minor=True)
axs[2].set_xticklabels(['2015','2016','2017','2018','2019','2020','2021'],rotation=0,minor=True)
#axs.tick_params(bottom = True, top = False, left = True, right = False)


axs[0].xaxis.set_major_locator(mdates.YearLocator(2))
axs[0].xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

axs[0].grid(which='minor',axis='both')
axs[1].grid(which='minor',axis='both')
axs[2].grid(which='minor',axis='both')

axs[0].grid(which='major',axis='both')
axs[1].grid(which='major',axis='both')
axs[2].grid(which='major',axis='both')


# add horizontal zero line for all plots 
axs[0].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)
axs[1].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)
axs[2].axhline(y=0, color = '#969696', linestyle='--', linewidth=1)
fig.tight_layout()

plt.savefig('D:/2021/la_plata/figures/anomalies/all_anomaly_updated_2022_subs_sm_volmetric_thi.png')

# %%
df.Up_Paraguay
# Out:
# 0     -9.990000e+08
# 1     -3.270000e-05
# 2     -5.430000e-06
# 3     -6.900000e-06
# 4     -1.070000e-05
#            ...
# 224   -1.120000e-05
# 225   -4.370000e-06
# 226    7.440000e-06
# 227    9.460000e-06
# 228             NaN
# Name: Up_Paraguay, Length: 229, dtype: float64

# %%
plt.rcParams["figure.figsize"]= [9, 3.5]
plt.rcParams["figure.autolayout"]= True

columns= ['Up_Paraguay','Lo_Paraguay','Up_Parana', 'Lo_Parana', 'Up_Ulguay','Lo_Ulguay','Rio_Plata','Laplata']
df= pd.read_csv('D:/2021/la_plata/subbasin_anoms_update/panom_gldas22_ts.csv', usecols= columns)
plt.style.use('tableau-colorblind10')



df.plot()
plt.show()

# %%
df=pd.read_csv('D:/2021/la_plata/subbasin_anoms_update/panom_gldas22_ts.csv')

#Make Variables from dataframe columns
Upper_Paraguay = df['Up_Paraguay']
Lower_Paraguay = df['Lo_Paraguay']
Upper_Parana = df['Up_Parana']
Lower_Parana = df['Lo_Parana']
Upper_Uruguay = df['Up_Ulguay']
Lower_Uruguay = df['Lo_Ulguay']
Rio_de_la_Plata = df['Rio_Plata']
Entire_Basin = df['Laplata']

#Setup Figure
fig = plt.figure(figsize=(6,3))
ax1 = fig.add_subplot(1,1,1)
ax1.set_title('Precipitation Anomalies in the Basin and Subbasins')
ax1.set_xlabel("Year")
ax1.set_ylabel("Precip Anomalies (mm)")

#plot lines by SectionName

plt.plot(Upper_Paraguay, Lower_Paraguay, Upper_Parana, Lower_Parana, Upper_Uruguay, Lower_Uruguay, Rio_de_la_Plata, Entire_Basin)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import netCDF4 
from scipy.io import netcdf
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd

# %%
data = 'E:/2021/la_plata/subbasin_anoms_update/'+'profile_depth_gldas22_laplata.nc'
nc= netCDF4.Dataset(data, mode= 'r')
nc.variables.keys()

lat = nc.variables['lat'][:]
lon = nc.variables['lon'][:]
depth = nc.variables ['var']

#depth_ts=pd.Series(depth, lat, lon)

#nc.var.to_dataframe().to_csv('depth.csv')

#DS=xr.open_dataset(data)

# %%
np.savetxt('depth.csv', depth, delimiter= ',')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\JESSIC~1\AppData\Local\Temp/ipykernel_22832/3620242944.py in <module>
# ----> 1 np.savetxt('depth.csv', depth, delimiter= ',').show()
#
# AttributeError: 'NoneType' object has no attribute 'show'

# %%
DS.values
# Out:
# <bound method Mapping.values of <xarray.Dataset>
# Dimensions:  (lat: 96, lon: 100)
# Coordinates:
#   * lat      (lat) float32 -37.88 -37.62 -37.38 -37.12 ... -14.62 -14.38 -14.12
#   * lon      (lon) float32 -67.88 -67.62 -67.38 -67.12 ... -43.62 -43.38 -43.12
# Data variables:
#     var      (lat, lon) float32 3.333e+03 3.333e+03 ... 3.907e+03 3.485e+03
# Attributes:
#     note:         +2m
#     source_file:  ECMWF, CSR_GRACE_GRACE-FO_RL06_Mascons_all-corrections_v02.nc
#     title:        GRACEFO_DA_CLSMF2.5_GLDAS2.2 BEDROCKDEPTH
#     history:      Mon May 23 17:00:47 2022: ncks -v var -d lon,-68.0,-43.0 -d...
#     NCO:          netCDF Operators version 5.0.1 (Homepage = http://nco.sf.ne...>

# %%
df= pd.DataFrame (data=DS['var'])

# %%
df
# Out:
#                                                    0   \
# 0   <xarray.DataArray 'var' ()>\narray(3333., dtyp...
# 1   <xarray.DataArray 'var' ()>\narray(3333., dtyp...
# 2   <xarray.DataArray 'var' ()>\narray(3333., dtyp...
# 3   <xarray.DataArray 'var' ()>\narray(3333., dtyp...
# 4   <xarray.DataArray 'var' ()>\narray(3333., dtyp...
# ..                                                ...
# 91  <xarray.DataArray 'var' ()>\narray(3333., dtyp...
# 92  <xarray.DataArray 'var' ()>\narray(3333., dtyp...
# 93  <xarray.DataArray 'var' ()>\narray(3547.264, d...
# 94  <xarray.DataArray 'var' ()>\narray(3923.002, d...
# 95  <xarray.DataArray 'var' ()>\narray(4218.9, dty...
#
#                                                    1   \
# 0   <xarray.DataArray 'var' ()>\narray(3333., dtyp...
# 1   <xarray.DataArray 'var' ()>\narray(3333., dtyp...
# 2   <xarray.DataArray 'var' ()>\narray(3333., dtyp...
# 3   <xarray.DataArray 'var' ()>\narray(3333., dtyp...
# ...

# %%
df[all].max()
# Out:
# <xarray.DataArray 'var' ()>
# array(4709.837, dtype=float32)
# Coordinates:
#     lat      float32 -21.38
#     lon      float32 -67.88
# Attributes:
#     long_name:  CLSMF2.5 depth to bedrock
#     units:      mm

# %%
df['average_all']= df.mean(axis=1)

# %%
df.mean(axis=1)
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#          ...
# 91    4947.787500
# 92    4927.577188
# 93    4957.854375
# 94    4951.927500
# 95    4851.487500
# Length: 96, dtype: float64

# %%
print(df['average_all'].mean())
# Out:
# 4516.3691360294115

# %%
print(df['average_all'].max())
# Out:
# 4958.19625

# %%
DS.var
# Out:
# <bound method ImplementsDatasetReduce._reduce_method.<locals>.wrapped_func of <xarray.Dataset>
# Dimensions:  (lat: 96, lon: 100)
# Coordinates:
#   * lat      (lat) float32 -37.88 -37.62 -37.38 -37.12 ... -14.62 -14.38 -14.12
#   * lon      (lon) float32 -67.88 -67.62 -67.38 -67.12 ... -43.62 -43.38 -43.12
# Data variables:
#     var      (lat, lon) float32 ...
# Attributes:
#     note:         +2m
#     source_file:  ECMWF, CSR_GRACE_GRACE-FO_RL06_Mascons_all-corrections_v02.nc
#     title:        GRACEFO_DA_CLSMF2.5_GLDAS2.2 BEDROCKDEPTH
#     history:      Mon May 23 17:00:47 2022: ncks -v var -d lon,-68.0,-43.0 -d...
#     NCO:          netCDF Operators version 5.0.1 (Homepage = http://nco.sf.ne...>
